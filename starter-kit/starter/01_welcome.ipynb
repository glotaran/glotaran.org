# %% [markdown]
# # Welcome to pyglotaran 👋
#
# You are looking at a **notebook**. A notebook is a document made of
# **cells**. Some cells are text (like this one) and some contain
# Python **code** that you can run.
#
# You do not need to know Python to use this starter kit. You just need
# to know how to **run a cell**:
#
# 1. Click once on a code cell to select it (the grey box below).
# 2. Press **Shift + Enter** on your keyboard.
# 3. The code runs, and the result appears underneath.
#
# That is the whole skill. Let's try it.

# %% [markdown]
# ## Try it now
#
# Click the cell below, then press **Shift + Enter**, or press the ▶ button.

# %%
print("It works! You just ran your first cell.")
1 + 1

# %% [markdown]
# The number `2` that appeared is the *result* of the last line.
# That is how a notebook shows you answers.
#
# ## Check that pyglotaran is installed
#
# Run the next cell. It loads the analysis software and prints its
# version. The first time may take a few seconds.

# %%
import glotaran
import pyglotaran_extras

print("pyglotaran   version:", glotaran.__version__)
print("pyglotaran-extras version:", pyglotaran_extras.__version__)
print()
print("Everything is installed. You are ready to go!")

# %% [markdown]
# ## What next?
#
# In the file browser on the **left**, open the next notebook:
#
# ### ➡️ `02_two_component.ipynb`
#
# It walks you through a complete analysis on a small dataset loaded from
# a **CSV file** — the kind of file you can open in Excel — so you see the
# whole workflow from start to finish. The notebooks after it build on it
# step by step:
#
# - `02_two_component.ipynb` — your first full analysis (two states).
# - `03_three_component.ipynb` — the same, with three states.
# - `04_fluorescence.ipynb` — a real, published fluorescence measurement.
# - `05_going_further.ipynb` — where to go next.
#
# ---
#
# ### A few tips
#
# - **Run cells in order, top to bottom.** Each one builds on the last.
# - If something looks stuck, look for `[*]` to the left of a cell: that
#   means it is still running. Wait for it to turn into a number.
# - To start over cleanly, use the menu: **Kernel → Restart Kernel and
#   Run All Cells**.
# - Your work is saved automatically, but you can also press
#   **Ctrl + S** (Windows/Linux) or **Cmd + S** (Mac) any time.
